# %% [markdown]
# <a href="https://colab.research.google.com/github/BalytskyiJaroslaw/PathogensRamanOpenSet/blob/main/BarCharts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

AFPMnaive10 = [[1, 0.0, 0.0],
 [2, 1.75, 0.4330127018922193],
 [3, 12.75, 2.277608394786075],
 [4, 44.75, 2.384848003542364],
 [5, 4.5, 0.5],
 [6, 46.5, 3.774917217635375],
 [7, 68.75, 3.2691742076555053],
 [8, 27.0, 1.224744871391589],
 [9, 99.0, 0.0],
 [10, 3.5, 2.29128784747792]]

AFPMentropic10FIRST5 = [[1, 2.0, 1.224744871391589],
 [2, 66.25, 2.5860201081971503],
 [3, 9.75, 3.112474899497183],
 [4, 74.75, 1.0897247358851685],
 [5, 42.5, 3.278719262151],
 [6, 99.0, 0.0],
 [7, 4.25, 0.82915619758885],
 [8, 25.25, 5.539629951540085],
 [9, 46.0, 10.295630140987],
 [10, 96.75, 1.6393596310755]]

AFPMobjectosphere10FIRST5 = [[1, 14.75, 3.2691742076555053],
 [2, 68.75, 4.968651728587948],
 [3, 5.25, 1.920286436967152],
 [4, 69.75, 8.642193008721803],
 [5, 73.0, 7.713624310270756],
 [6, 99.75, 0.4330127018922193],
 [7, 5.5, 0.5],
 [8, 55.5, 2.0615528128088303],
 [9, 29.25, 5.584576975922169],
 [10, 96.5, 1.5]]

x1, y1, err1 = zip(*AFPMnaive10)
x2, y2, err2 = zip(*AFPMentropic10FIRST5)
x3, y3, err3 = zip(*AFPMobjectosphere10FIRST5)

x_labels = [f'Label {i}' for i in range(1, len(x1) + 1)]

x_labels[0] = 'Group A Strep'
x_labels[1] = 'Group B Strep'
x_labels[2] = 'Group C Strep'
x_labels[3] = 'Group G Strep'
x_labels[4] = 'E. coli 1'
x_labels[5] = 'E. coli 2'
x_labels[6] = 'E. cloacae'
x_labels[7] = 'P. mirabilis'
x_labels[8] = 'S. marcescens'
x_labels[9] = 'C. albicans'

bar_width = 0.25

x_shift1 = np.arange(len(x1)) - bar_width
x_shift2 = np.arange(len(x2))
x_shift3 = np.arange(len(x3)) + bar_width

plt.figure(figsize=(12, 6))

plt.bar(x_shift1, y1, width=bar_width, edgecolor='red', hatch='....', label=r'Naive, $\mathcal{K} = p_1 + p_3$, $\mathcal{I} = \emptyset$,' '\n Average over $p_1 = 30.9 \pm 1.2\%$')
plt.bar(x_shift2, y2, width=bar_width, edgecolor='green', fill=False, hatch='\\\\', label=r'ENT, $\mathcal{K} = p_1$, $\mathcal{I} = p_3$' '\n Average over $p_1 = 46.7 \pm 1.4\%$')
plt.bar(x_shift3, y3, width=bar_width, edgecolor='blue', fill=False, hatch='////', label=r'Obj., $\mathcal{K} = p_1$, $\mathcal{I} = p_3$' '\n Average over $p_1 = 51.8 \pm 1.8\%$')

plt.errorbar(x_shift1, y1, yerr=err1, fmt='none', ecolor='black', capsize=5)
plt.errorbar(x_shift2, y2, yerr=err2, fmt='none', ecolor='black', capsize=5)
plt.errorbar(x_shift3, y3, yerr=err3, fmt='none', ecolor='black', capsize=5)

plt.xticks(np.arange(len(x1)), x_labels, rotation='vertical', fontsize=16)

plt.ylabel('Probability, above per-class threshold, \n FP = 0 and error rate = 0', fontsize=20)
plt.title(r'Comparison over 10 classes of interest $p_1$', fontsize=24)

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=14)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

AFPMnaive15 = [[1, 11.25, 3.112474899497183],
 [2, 46.25, 4.763139720814412],
 [3, 11.5, 0.8660254037844386],
 [4, 75.75, 2.947456530637899],
 [5, 51.75, 11.519006033508273],
 [6, 35.25, 2.0463381929681126],
 [7, 54.25, 6.098155458825234],
 [8, 82.0, 0.0],
 [9, 90.0, 0.0],
 [10, 8.25, 2.5860201081971503],
 [11, 38.25, 6.339361166552983],
 [12, 0.25, 0.4330127018922193],
 [13, 1.25, 1.299038105676658],
 [14, 99.0, 0.0],
 [15, 72.0, 2.1213203435596424]]

AFPMnaive20 = [[1, 16.25, 14.072912811497128],
 [2, 2.75, 0.82915619758885],
 [3, 9.5, 3.278719262151],
 [4, 35.25, 2.165063509461097],
 [5, 9.75, 1.0897247358851685],
 [6, 65.5, 5.123475382979799],
 [7, 70.75, 6.378675411086537],
 [8, 66.5, 4.55521678957215],
 [9, 33.5, 5.408326913195984],
 [10, 60.25, 4.380353866983808],
 [11, 35.75, 5.84700778176325],
 [12, 91.0, 0.0],
 [13, 28.5, 0.5],
 [14, 6.5, 1.8027756377319946],
 [15, 40.25, 2.7726341266023544]]

AFPMentropic15FIRST5 = [[1, 3.0, 1.7320508075688772],
 [2, 71.75, 1.479019945774904],
 [3, 12.25, 2.7726341266023544],
 [4, 76.25, 1.0897247358851685],
 [5, 99.0, 0.7071067811865476],
 [6, 42.0, 4.358898943540674],
 [7, 70.75, 2.5860201081971503],
 [8, 58.75, 4.437059837324712],
 [9, 84.0, 2.449489742783178],
 [10, 3.25, 0.4330127018922193],
 [11, 37.5, 3.774917217635375],
 [12, 44.0, 6.48074069840786],
 [13, 35.0, 6.96419413859206],
 [14, 99.0, 0.0],
 [15, 95.25, 0.4330127018922193]]

AFPMobjectosphere15FIRST5 = [[1, 8.5, 3.840572873934304],
 [2, 70.75, 3.2691742076555053],
 [3, 8.75, 2.384848003542364],
 [4, 68.0, 6.123724356957945],
 [5, 97.25, 0.4330127018922193],
 [6, 38.5, 2.29128784747792],
 [7, 66.5, 6.020797289396148],
 [8, 60.75, 3.897114317029974],
 [9, 89.75, 0.4330127018922193],
 [10, 5.25, 2.277608394786075],
 [11, 52.75, 7.258615570478987],
 [12, 28.5, 7.365459931328117],
 [13, 43.0, 10.559356040971437],
 [14, 99.0, 0.0],
 [15, 93.5, 1.5]]

x1, y1, err1 = zip(*AFPMnaive15)
x2, y2, err2 = zip(*AFPMnaive20)
x3, y3, err3 = zip(*AFPMentropic15FIRST5)
x4, y4, err4 = zip(*AFPMobjectosphere15FIRST5)

x_labels = [f'Label {i}' for i in range(1, len(x1) + 1)]

x_labels[0] = 'Group A Strep'
x_labels[1] = 'Group B Strep'
x_labels[2] = 'Group C Strep'
x_labels[3] = 'Group G Strep'
x_labels[4] = 'E. coli 1'
x_labels[5] = 'E. coli 2'
x_labels[6] = 'E. cloacae'
x_labels[7] = 'P. mirabilis'
x_labels[8] = 'S. marcescens'
x_labels[9] = 'C. albicans'
x_labels[10] = 'E. faecalis 1'
x_labels[11] = 'E. faecalis 2'
x_labels[12] = 'E. faecium'
x_labels[13] = 'P. aeruginosa 1'
x_labels[14] = 'P. aeruginosa 2'

bar_width = 0.2

x_shift1 = np.arange(len(x1)) - bar_width*1.5
x_shift2 = np.arange(len(x2)) - bar_width/2
x_shift3 = np.arange(len(x3)) + bar_width/2
x_shift4 = np.arange(len(x4)) + bar_width*1.5

plt.figure(figsize=(16, 8))

plt.bar(x_shift1, y1, width=bar_width, color='#1E88E5', hatch='.', label=r'Naive, $\mathcal{K} = p_1 + p_2$, $\mathcal{I} = \emptyset$, ' '\n Average over $p_1 + p_2 = 45.1 \pm 0.4 \%$')
plt.bar(x_shift2, y2, width=bar_width, edgecolor='#004D40', fill=False, hatch='....', label=r'Naive, $\mathcal{K} = p_1 + p_2 + p_3$, $\mathcal{I} = \emptyset$, ' '\n Average over $p_1 + p_2 = 38.1 \pm 2.1 \%$')
plt.bar(x_shift3, y3, width=bar_width, edgecolor='#7536DE', fill=False, hatch='\\\\', label=r'ENT, $\mathcal{K} = p_1$, $\mathcal{I} = p_3$' '\n Average over $p_1 + p_2 = 55.5 \pm 1.4 \%$')
plt.bar(x_shift4, y4, width=bar_width, edgecolor='#FF00FF', fill=False, hatch='////', label=r'Obj., $\mathcal{K} = p_1$, $\mathcal{I} = p_3$' '\n Average over $p_1 + p_2 = 55.4 \pm 1.8 \%$')


plt.errorbar(x_shift1, y1, yerr=err1, fmt='none', ecolor='black', capsize=2)
plt.errorbar(x_shift2, y2, yerr=err2, fmt='none', ecolor='black', capsize=2)
plt.errorbar(x_shift3, y3, yerr=err3, fmt='none', ecolor='black', capsize=2)
plt.errorbar(x_shift4, y4, yerr=err4, fmt='none', ecolor='black', capsize=2)

plt.xticks(np.arange(len(x1)), x_labels, rotation='vertical', fontsize=12)

plt.ylabel('Probability, above per-class threshold, \n FP = 0 and error rate = 0', fontsize=20)
plt.title(r'Comparison over 15 classes of interest $p_1 + p_2$', fontsize=24)

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=14)

plt.tight_layout()
plt.show()

# %%
from google.colab import drive

drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Compute ODINs

# %% [markdown]
# # Naive $\mathcal{K} = p_1$, $\mathcal{I} = ∅$

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

folder_path = "/content/gdrive/MyDrive/Stanford_data"

file_name = "all_odin_scores_NAIVEKp1.txt"

file_path = os.path.join(folder_path, file_name)

retrieved_odin_scores = []

if os.path.exists(file_path):
    with open(file_path, 'r') as file:
        retrieved_odin_scoresK_p1 = [float(line.strip()) for line in file.readlines()]

# %%
plt.hist(retrieved_odin_scoresK_p1, bins=10)

plt.xlabel('ODIN Score')
plt.ylabel('Frequency')
plt.title('Histogram of ODIN UNKNOWN Scores')

plt.show()

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

folder_path = "/content/gdrive/MyDrive/Stanford_data"

file_name = "KNOWN_all_odin_scores_NAIVEKp1.txt"

file_path = os.path.join(folder_path, file_name)

KNOWN_retrieved_odin_scoresK_p1 = []

if os.path.exists(file_path):
    with open(file_path, 'r') as file:
        KNOWN_retrieved_odin_scoresK_p1 = [float(line.strip()) for line in file.readlines()]

# %%
plt.hist(KNOWN_retrieved_odin_scoresK_p1, bins=10)

plt.xlabel('ODIN Score')
plt.ylabel('Frequency')
plt.title('Histogram of ODIN KNOWN Scores')

plt.show()

# %%
min(retrieved_odin_scoresK_p1)
# Out:
# 0.00878184475004673

# %%
max(KNOWN_retrieved_odin_scoresK_p1)
# Out:
# 2.6193447411060333e-08

# %% [markdown]
# # Naive, $\mathcal{K} = p_1 + p_3$, $\mathcal{I} = \emptyset$

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

folder_path = "/content/gdrive/MyDrive/Stanford_data"

file_name = "all_odin_scores_NAIVEKp1p3.txt"

file_path = os.path.join(folder_path, file_name)

retrieved_odin_scores = []

if os.path.exists(file_path):
    with open(file_path, 'r') as file:
        retrieved_odin_scoresK_p1p3 = [float(line.strip()) for line in file.readlines()]

# %%
plt.hist(retrieved_odin_scoresK_p1p3, bins=10)
plt.xlabel('ODIN Score')
plt.ylabel('Frequency')
plt.title('Histogram of ODIN UNKNOWN Scores')

plt.show()

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

folder_path = "/content/gdrive/MyDrive/Stanford_data"

file_name = "KNOWN_all_odin_scores_NAIVEKp1p3.txt"

file_path = os.path.join(folder_path, file_name)

KNOWN_retrieved_odin_scoresK_p1p3 = []

if os.path.exists(file_path):
    with open(file_path, 'r') as file:
        KNOWN_retrieved_odin_scoresK_p1p3 = [float(line.strip()) for line in file.readlines()]

# %%
plt.hist(KNOWN_retrieved_odin_scoresK_p1p3, bins=10)

plt.xlabel('ODIN Score')
plt.ylabel('Frequency')
plt.title('Histogram of ODIN KNOWN Scores')

plt.show()

# %%
min(retrieved_odin_scoresK_p1p3)
# Out:
# 0.015538706444203854

# %%
max(KNOWN_retrieved_odin_scoresK_p1p3)
# Out:
# 3.457535058259964e-08

# %% [markdown]
# 0.015538706444203854,3.457535058259964e-08

# %% [markdown]
# #EOS $\mathcal{K} = p_1$, $\mathcal{I} = p_3$

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

folder_path = "/content/gdrive/MyDrive/Stanford_data"

file_name = "all_odin_scores_EOS_p1p3.txt"

file_path = os.path.join(folder_path, file_name)

retrieved_odin_scores = []

if os.path.exists(file_path):
    with open(file_path, 'r') as file:
        retrieved_odin_scoresEOS_p1p3 = [float(line.strip()) for line in file.readlines()]

# %%
plt.hist(retrieved_odin_scoresEOS_p1p3, bins=10)

plt.xlabel('ODIN Score')
plt.ylabel('Frequency')
plt.title('Histogram of ODIN UNKNOWN Scores')

plt.show()

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

folder_path = "/content/gdrive/MyDrive/Stanford_data"

file_name = "KNOWN_all_odin_scores_EOSp1p3.txt"

file_path = os.path.join(folder_path, file_name)

KNOWN_retrieved_odin_scoresK_p1 = []

if os.path.exists(file_path):
    with open(file_path, 'r') as file:
        KNOWN_retrieved_odin_scoresEOS_p1p3 = [float(line.strip()) for line in file.readlines()]

# %%
plt.hist(KNOWN_retrieved_odin_scoresEOS_p1p3, bins=10)

plt.xlabel('ODIN Score')
plt.ylabel('Frequency')
plt.title('Histogram of ODIN KNOWN Scores')

plt.show()

# %%
min(retrieved_odin_scoresEOS_p1p3)
# Out:
# 0.00013694577501155436

# %%
max(KNOWN_retrieved_odin_scoresEOS_p1p3)
# Out:
# 6.2282197177410126e-09

# %% [markdown]
# # Obj, $\mathcal{K} = p_1$, $\mathcal{I} = p_3$

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

folder_path = "/content/gdrive/MyDrive/Stanford_data"

file_name = "all_odin_scores_OBJ_p1p3.txt"

file_path = os.path.join(folder_path, file_name)

retrieved_odin_scores = []

if os.path.exists(file_path):
    with open(file_path, 'r') as file:
        retrieved_odin_scoresOBJ_p1p3 = [float(line.strip()) for line in file.readlines()]

# %%
plt.hist(retrieved_odin_scoresOBJ_p1p3, bins=10)

plt.xlabel('ODIN Score')
plt.ylabel('Frequency')
plt.title('Histogram of ODIN UNKNOWN Scores')

plt.show()

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

folder_path = "/content/gdrive/MyDrive/Stanford_data"

file_name = "KNOWN_all_odin_scores_OBJp1p3.txt"

file_path = os.path.join(folder_path, file_name)

if os.path.exists(file_path):
    with open(file_path, 'r') as file:
        KNOWN_retrieved_odin_scoresOBJ_p1p3 = [float(line.strip()) for line in file.readlines()]

# %%
plt.hist(KNOWN_retrieved_odin_scoresOBJ_p1p3, bins=10)

plt.xlabel('ODIN Score')
plt.ylabel('Frequency')
plt.title('Histogram of ODIN KNOWN Scores')

plt.show()

# %%
min(retrieved_odin_scoresOBJ_p1p3)
# Out:
# 0.035471729934215546

# %%
max(KNOWN_retrieved_odin_scoresOBJ_p1p3)
# Out:
# 4.716217517852783e-06

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.hist(retrieved_odin_scoresK_p1, bins=30, alpha=0.5, color='blue', label='Naive, $\mathcal{K} = p_1$, $\mathcal{I} = \emptyset$')
plt.hist(retrieved_odin_scoresK_p1p3, bins=30, alpha=0.5, color='red', label='Naive, $\mathcal{K} = p_1 + p_3$, $\mathcal{I} = \emptyset$')
plt.hist(retrieved_odin_scoresOBJ_p1p3, bins=30, alpha=0.5, color='green', label='Objectosphere, $\mathcal{K} = p_1$, $\mathcal{I} = p_3$')

plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend(loc='upper right')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.hist(retrieved_odin_scoresK_p1, bins=30, alpha=0.5, color='blue', hatch='/', label='Naive, $\mathcal{K} = p_1$, $\mathcal{I} = \emptyset$')
plt.hist(retrieved_odin_scoresK_p1p3, bins=30, alpha=0.5, color='red', hatch='\\', label='Naive, $\mathcal{K} = p_1 + p_3$, $\mathcal{I} = \emptyset$')
plt.hist(retrieved_odin_scoresOBJ_p1p3, bins=30, alpha=0.5, color='green', hatch='.', label='Objectosphere, $\mathcal{K} = p_1$, $\mathcal{I} = p_3$')

plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend(loc='upper right')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.hist(retrieved_odin_scoresK_p1, bins=50, alpha=0.7, color='blue', edgecolor='black', hatch='/', label='Naive, $\mathcal{K} = p_1$, $\mathcal{I} = \emptyset$')
plt.hist(retrieved_odin_scoresK_p1p3, bins=50, alpha=0.7, color='red', edgecolor='black', hatch='\\', label='Naive, $\mathcal{K} = p_1 + p_3$, $\mathcal{I} = \emptyset$')
plt.hist(retrieved_odin_scoresOBJ_p1p3, bins=50, alpha=0.7, color='green', edgecolor='black', hatch='.', label='Objectosphere, $\mathcal{K} = p_1$, $\mathcal{I} = p_3$')

plt.title('$\mathcal{N}$ ODIN scores, using $p_1$ and $p_3$ datasets')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend(loc='upper right')
plt.grid(False)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.hist(retrieved_odin_scoresK_p1, bins=50, alpha=0.7, color='blue', edgecolor='black', hatch='//', label='Naive, $\mathcal{K} = p_1$, $\mathcal{I} = \emptyset$,' '\n  $max(\mathcal{K}) = 8.8 \cdot 10^{-3}$, $min(\mathcal{N}) = 2.6\cdot 10^{-8}$', linewidth=0.5)
plt.hist(retrieved_odin_scoresK_p1p3, bins=50, alpha=0.7, color='#FFC107', edgecolor='black', hatch='\\\\', label='Naive, $\mathcal{K} = p_1 + p_3$, $\mathcal{I} = \emptyset$,' '\n  $max(\mathcal{K}) = 1.6 \cdot 10^{-2}$, $min(\mathcal{N}) = 3.4\cdot 10^{-8}$', linewidth=0.5)
plt.hist(retrieved_odin_scoresOBJ_p1p3, bins=50, alpha=0.7, color='green', edgecolor='black', hatch='.', label='Objectosphere, $\mathcal{K} = p_1$, $\mathcal{I} = p_3$,' '\n  $max(\mathcal{K}) = 3.5 \cdot 10^{-2}$, $min(\mathcal{N}) = 4.7\cdot 10^{-6}$', linewidth=0.5)

plt.title('ODIN scores of $\mathcal{N}$ , using $p_1$ and $p_3$ datasets')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend(loc='upper right')
plt.grid(False)

plt.show()

# %% [markdown]
# # OpenMax

# %% [markdown]
# # Naive, $\mathcal{K} = p_1$, $\mathcal{I} = \emptyset$

# %%
import numpy as np
import matplotlib.pyplot as plt

file_path_known = '/content/gdrive/MyDrive/Stanford_data/NaiveKp1_combined_openmax_scores_known.txt'
file_path_unknown = '/content/gdrive/MyDrive/Stanford_data/NaiveKp1_combined_openmax_scores_unknown.txt'

openmax_scores_known_NaiveKp1 = np.loadtxt(file_path_known)
openmax_scores_unknown_NaiveKp1 = np.loadtxt(file_path_unknown)

plt.hist(openmax_scores_known_NaiveKp1, bins=50, alpha=0.5, color='blue', label='Known Data')
plt.hist(openmax_scores_unknown_NaiveKp1, bins=50, alpha=0.5, color='red', label='Unknown Data')
plt.xlabel('OpenMax Score')
plt.ylabel('Frequency')
plt.title('Histogram of OpenMax Scores')
plt.legend(loc='upper right')

plt.show()

# %%
min(openmax_scores_unknown_NaiveKp1)
# Out:
# 1.523441187600838e-05

# %%
import numpy as np

threshold = min(openmax_scores_unknown_NaiveKp1)

percentage_below_threshold = np.mean(openmax_scores_known_NaiveKp1 < threshold) * 100

print(f"Percentage of values below {threshold}: {percentage_below_threshold:.2f}%")
# Out:
# Percentage of values below 1.523441187600838e-05: 41.66%

# %% [markdown]
# # Naive, $\mathcal{K} = p_1 + p_3$, $\mathcal{I} = \emptyset$

# %%
import numpy as np
import matplotlib.pyplot as plt

file_path_known = '/content/gdrive/MyDrive/Stanford_data/NaiveKp1p3_combined_openmax_scores_known.txt'
file_path_unknown = '/content/gdrive/MyDrive/Stanford_data/NaiveKp1p3_combined_openmax_scores_unknown.txt'

openmax_scores_known_Naivep1p3 = np.loadtxt(file_path_known)
openmax_scores_unknown_Naivep1p3 = np.loadtxt(file_path_unknown)

plt.hist(openmax_scores_known_Naivep1p3, bins=50, alpha=0.5, color='blue', label='Known Data')
plt.hist(openmax_scores_unknown_Naivep1p3, bins=50, alpha=0.5, color='red', label='Unknown Data')
plt.xlabel('OpenMax Score')
plt.ylabel('Frequency')
plt.title('Histogram of OpenMax Scores')
plt.legend(loc='upper right')

plt.show()

# %%
import numpy as np

threshold = min(openmax_scores_unknown_Naivep1p3)

percentage_below_threshold = np.mean(openmax_scores_known_Naivep1p3 < threshold) * 100

print(f"Percentage of values below {threshold}: {percentage_below_threshold:.2f}%")
# Out:
# Percentage of values below 6.874096669662322e-08: 54.46%

# %% [markdown]
# #EOS, $\mathcal{K} = p_1$, $\mathcal{I} = p_3$

# %%
import numpy as np
import matplotlib.pyplot as plt

file_path_known = '/content/gdrive/MyDrive/Stanford_data/EOSp1p3_combined_openmax_scores_known.txt'
file_path_unknown = '/content/gdrive/MyDrive/Stanford_data/EOSp1p3_combined_openmax_scores_unknown.txt'

openmax_scores_known_EOSp1p3 = np.loadtxt(file_path_known)
openmax_scores_unknown_EOSp1p3 = np.loadtxt(file_path_unknown)

plt.hist(openmax_scores_known_EOSp1p3, bins=50, alpha=0.5, color='blue', label='Known Data')
plt.hist(openmax_scores_unknown_EOSp1p3, bins=50, alpha=0.5, color='red', label='Unknown Data')
plt.xlabel('OpenMax Score')
plt.ylabel('Frequency')
plt.title('Histogram of OpenMax Scores')
plt.legend(loc='upper right')

plt.show()

# %%
import numpy as np

threshold = min(openmax_scores_unknown_EOSp1p3)

percentage_below_threshold = np.mean(openmax_scores_known_EOSp1p3 < threshold) * 100

print(f"Percentage of values below {threshold}: {percentage_below_threshold:.2f}%")
# Out:
# Percentage of values below 0.00012809842883143574: 83.66%

# %% [markdown]
# # Obj, $\mathcal{K} = p_1$, $\mathcal{I} = p_3$

# %%
import numpy as np
import matplotlib.pyplot as plt

file_path_known = '/content/gdrive/MyDrive/Stanford_data/OBJp1p3_combined_openmax_scores_known.txt'
file_path_unknown = '/content/gdrive/MyDrive/Stanford_data/OBJp1p3_combined_openmax_scores_unknown.txt'

openmax_scores_known_OBJp1p3 = np.loadtxt(file_path_known)
openmax_scores_unknown_OBJp1p3 = np.loadtxt(file_path_unknown)

plt.hist(openmax_scores_known_OBJp1p3, bins=50, alpha=0.5, color='blue', label='Known Data')
plt.hist(openmax_scores_unknown_OBJp1p3, bins=50, alpha=0.5, color='red', label='Unknown Data')
plt.xlabel('OpenMax Score')
plt.ylabel('Frequency')
plt.title('Histogram of OpenMax Scores')
plt.legend(loc='upper right')

plt.show()

# %%
import numpy as np

threshold = min(openmax_scores_unknown_OBJp1p3)

percentage_below_threshold = np.mean(openmax_scores_known_OBJp1p3 < threshold) * 100

print(f"Percentage of values below {threshold}: {percentage_below_threshold:.2f}%")
# Out:
# Percentage of values below 2.836067096723127e-06: 28.59%

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.hist(openmax_scores_unknown_NaiveKp1, bins=50, alpha=0.7, color='blue', edgecolor='black', hatch='//', label='Naive, $\mathcal{K} = p_1$, $\mathcal{I} = \emptyset$')
plt.hist(openmax_scores_unknown_Naivep1p3, bins=50, alpha=0.7, color='red', edgecolor='black', hatch='\\\\', label='Naive, $\mathcal{K} = p_1 + p_3$')
plt.hist(openmax_scores_unknown_OBJp1p3, bins=50, alpha=0.7, color='green', edgecolor='black', hatch='.', label='Objectosphere, $\mathcal{K} = p_1$, $\mathcal{I} = p_3$')

plt.title('OpenMax scores of $\mathcal{N}$ , using $p_1$ and $p_3$ datasets')
plt.xlabel('Value of the OpenMax score')
plt.ylabel('Frequency of occurrence')
plt.legend(loc='upper center')
plt.grid(False)

plt.show()

# %% [markdown]
# # Mahalanobis

# %% [markdown]
# # Naive $\mathcal{K} = p_1$, $\mathcal{I} = \emptyset$

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

folder_path = "/content/gdrive/MyDrive/Stanford_data"

file_name = "mahalanobis_distances_unknown_combined_Naivep1.txt"

file_path = os.path.join(folder_path, file_name)

retrieved_Maha_scoresNaive_p1 = []

if os.path.exists(file_path):
    with open(file_path, 'r') as file:
        retrieved_Maha_scoresNaive_p1 = [float(line.strip()) for line in file.readlines()]

# %%
plt.hist(retrieved_Maha_scoresNaive_p1, bins=10)

plt.xlabel('Mahalanobis Score')
plt.ylabel('Frequency')
plt.title('Histogram of Mahalanobis UNKNOWN Scores')

plt.show()

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

folder_path = "/content/gdrive/MyDrive/Stanford_data"

file_name = "mahalanobis_distances_known_combined_Naivep1.txt"

file_path = os.path.join(folder_path, file_name)

KNOWN_retrieved_Maha_scoresNaive_p1 = []

if os.path.exists(file_path):
    with open(file_path, 'r') as file:
        KNOWN_retrieved_Maha_scoresNaive_p1 = [float(line.strip()) for line in file.readlines()]

# %%
plt.hist(KNOWN_retrieved_Maha_scoresNaive_p1, bins=10)

plt.xlabel('Mahalanobis Score')
plt.ylabel('Frequency')
plt.title('Histogram of Mahalanobis KNOWN Scores')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.hist(retrieved_Maha_scoresNaive_p1, bins=50, alpha=0.7, color='blue', edgecolor='black', hatch='/', label='Retrieved Mahalanobis Scores')
plt.hist(KNOWN_retrieved_Maha_scoresNaive_p1, bins=50, alpha=0.7, color='red', edgecolor='black', hatch='\\', label='KNOWN Retrieved Mahalanobis Scores')

plt.title('Comparison of Retrieved Mahalanobis Scores')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend(loc='upper right')
plt.grid(False)

plt.show()

# %% [markdown]
# # Naive $\mathcal{K} = p_1 + p_3$, $\mathcal{I} = \emptyset$

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

folder_path = "/content/gdrive/MyDrive/Stanford_data"

file_name = "mahalanobis_distances_unknown_combined_Naivep1p3.txt"

file_path = os.path.join(folder_path, file_name)

retrieved_Maha_scoresNaive_p1p3 = []

if os.path.exists(file_path):
    with open(file_path, 'r') as file:
        retrieved_Maha_scoresNaive_p1p3 = [float(line.strip()) for line in file.readlines()]

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

folder_path = "/content/gdrive/MyDrive/Stanford_data"

file_name = "mahalanobis_distances_known_combined_Naivep1p3.txt"

file_path = os.path.join(folder_path, file_name)

KNOWN_retrieved_Maha_scoresNaive_p1p3 = []

if os.path.exists(file_path):
    with open(file_path, 'r') as file:
        KNOWN_retrieved_Maha_scoresNaive_p1p3 = [float(line.strip()) for line in file.readlines()]

# %%
plt.hist(KNOWN_retrieved_Maha_scoresNaive_p1p3, bins=10)

plt.xlabel('Mahalanobis Score')
plt.ylabel('Frequency')
plt.title('Histogram of Mahalanobis KNOWN Scores')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.hist(retrieved_Maha_scoresNaive_p1p3, bins=20, alpha=0.7, color='blue', edgecolor='black', hatch='/', label='Retrieved Mahalanobis Scores')
plt.hist(KNOWN_retrieved_Maha_scoresNaive_p1p3, bins=20, alpha=0.7, color='red', edgecolor='black', hatch='\\', label='KNOWN Retrieved Mahalanobis Scores')

plt.title('Comparison of Retrieved Mahalanobis Scores')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend(loc='upper right')
plt.grid(False)

plt.show()

# %% [markdown]
# # EOS $\mathcal{K} = p_1$, $\mathcal{I} = p_3$

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

folder_path = "/content/gdrive/MyDrive/Stanford_data"

file_name = "mahalanobis_distances_unknown_combined_EOSp1p3.txt"

file_path = os.path.join(folder_path, file_name)

retrieved_Maha_scoresEOS_p1p3 = []

if os.path.exists(file_path):
    with open(file_path, 'r') as file:
        retrieved_Maha_scoresEOS_p1p3 = [float(line.strip()) for line in file.readlines()]

# %%
plt.hist(retrieved_Maha_scoresEOS_p1p3, bins=10)

plt.xlabel('Mahalanobis Score')
plt.ylabel('Frequency')
plt.title('Histogram of Mahalanobis UNKNOWN Scores')

plt.show()

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

folder_path = "/content/gdrive/MyDrive/Stanford_data"

file_name = "mahalanobis_distances_known_combined_EOSp1p3.txt"

file_path = os.path.join(folder_path, file_name)

KNOWN_retrieved_Maha_scoresEOS_p1p3 = []

if os.path.exists(file_path):
    with open(file_path, 'r') as file:
        KNOWN_retrieved_Maha_scoresEOS_p1p3 = [float(line.strip()) for line in file.readlines()]

# %%
plt.hist(KNOWN_retrieved_Maha_scoresEOS_p1p3, bins=10)

plt.xlabel('Mahalanobis Score')
plt.ylabel('Frequency')
plt.title('Histogram of Mahalanobis KNOWN Scores')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.hist(retrieved_Maha_scoresEOS_p1p3, bins=50, alpha=0.7, color='blue', edgecolor='black', hatch='/', label='Retrieved Mahalanobis Scores')
plt.hist(KNOWN_retrieved_Maha_scoresEOS_p1p3, bins=50, alpha=0.7, color='red', edgecolor='black', hatch='\\', label='KNOWN Retrieved Mahalanobis Scores')

plt.title('Comparison of Retrieved Mahalanobis Scores')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend(loc='upper right')
plt.grid(False)

plt.show()

# %% [markdown]
# # OBJ $\mathcal{K} = p_1$, $\mathcal{I} = p_3$

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

folder_path = "/content/gdrive/MyDrive/Stanford_data"

file_name = "mahalanobis_distances_unknown_combined_OBJp1p3.txt"

file_path = os.path.join(folder_path, file_name)

retrieved_Maha_scoresOBJ_p1p3 = []

if os.path.exists(file_path):
    with open(file_path, 'r') as file:
        retrieved_Maha_scoresOBJ_p1p3 = [float(line.strip()) for line in file.readlines()]

# %%
plt.hist(retrieved_Maha_scoresOBJ_p1p3, bins=10)

plt.xlabel('Mahalanobis Score')
plt.ylabel('Frequency')
plt.title('Histogram of Mahalanobis UNKNOWN Scores')

plt.show()

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

folder_path = "/content/gdrive/MyDrive/Stanford_data"

file_name = "mahalanobis_distances_known_combined_OBJp1p3.txt"

file_path = os.path.join(folder_path, file_name)

KNOWN_retrieved_Maha_scoresOBJ_p1p3 = []

if os.path.exists(file_path):
    with open(file_path, 'r') as file:
        KNOWN_retrieved_Maha_scoresOBJ_p1p3 = [float(line.strip()) for line in file.readlines()]

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.hist(retrieved_Maha_scoresOBJ_p1p3, bins=50, alpha=0.7, color='blue', edgecolor='black', hatch='/', label='Retrieved Mahalanobis Scores')
plt.hist(KNOWN_retrieved_Maha_scoresOBJ_p1p3, bins=50, alpha=0.7, color='red', edgecolor='black', hatch='\\', label='KNOWN Retrieved Mahalanobis Scores')

plt.title('Comparison of Retrieved Mahalanobis Scores')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend(loc='upper right')
plt.grid(False)

plt.show()

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1, 3, figsize=(18, 6))

axs[0].hist([retrieved_odin_scoresOBJ_p1p3, KNOWN_retrieved_odin_scoresOBJ_p1p3], bins=25, label=['Samples belonging to the knowns', 'Never seen before samples'])
axs[0].set_xlabel('Value of the ODIN score')
axs[0].set_ylabel('Frequency of occurrence')
axs[0].set_title('Comparison of ODIN scores, Obj., $\mathcal{K} = p_1$, $\mathcal{I} = p_3$')
axs[0].legend()

axs[1].hist([openmax_scores_known_OBJp1p3, openmax_scores_unknown_OBJp1p3], bins=25, label=['Samples belonging to the knowns', 'Never seen before samples'])
axs[1].set_xlabel('Value of the OpenMax score')
axs[1].set_ylabel('Frequency of occurrence')
axs[1].set_title('Comparison of OpenMax scores, Obj., $\mathcal{K} = p_1$, $\mathcal{I} = p_3$')
axs[1].legend()

axs[2].hist([retrieved_Maha_scoresOBJ_p1p3, KNOWN_retrieved_Maha_scoresOBJ_p1p3], bins=25, label=['Samples belonging to the knowns', 'Never seen before samples'])
axs[2].set_xlabel('Value of the Mahalanobis score')
axs[2].set_ylabel('Frequency of occurrence')
axs[2].set_title('Comparison of Mahalanobis scores, Obj., $\mathcal{K} = p_1$, $\mathcal{I} = p_3$')
axs[2].legend()

plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.hist(retrieved_odin_scoresOBJ_p1p3, bins=20, alpha=0.7, color='blue', edgecolor='black', hatch='/', label='Samples belonging to the knowns')
plt.hist(KNOWN_retrieved_odin_scoresOBJ_p1p3, bins=20, alpha=0.7, color='red', edgecolor='black', hatch='\\', label='Never seen before samples')

plt.title('ODIN scores of $\mathcal{K}$ and $\mathcal{N}$, Obj., $\mathcal{K} = p_1$, $\mathcal{I} = p_3$')
plt.xlabel('Value of the ODIN score')
plt.ylabel('Frequency of occurrence')
plt.legend(loc='upper right')
plt.grid(False)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.hist(openmax_scores_known_OBJp1p3, bins=50, alpha=0.7, color='blue', edgecolor='black', hatch='/', label='Samples belonging to the knowns')
plt.hist(openmax_scores_unknown_OBJp1p3, bins=50, alpha=0.7, color='#FFC107', edgecolor='black', hatch='\\', label='Never seen before samples')

plt.title('OpenMax scores of $\mathcal{K}$ and $\mathcal{N}$, Obj., $\mathcal{K} = p_1$, $\mathcal{I} = p_3$')
plt.xlabel('Value of the OpenMax score')
plt.ylabel('Frequency of occurrence')
plt.legend(loc='upper right')
plt.grid(False)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.hist(retrieved_Maha_scoresOBJ_p1p3, bins=20, alpha=0.7, color='blue', edgecolor='black', hatch='/', label='Samples belonging to the knowns')
plt.hist(KNOWN_retrieved_Maha_scoresOBJ_p1p3, bins=20, alpha=0.7, color='red', edgecolor='black', hatch='\\', label='Never seen before samples')

plt.title('Mahalanobis scores of $\mathcal{K}$ and $\mathcal{N}$, Obj., $\mathcal{K} = p_1$, $\mathcal{I} = p_3$')
plt.xlabel('Value of Mahalanobis score')
plt.ylabel('Frequency of occurrence')
plt.legend(loc='upper right')
plt.grid(False)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, axs = plt.subplots(1, 3, figsize=(18, 4))

axs[0].hist(KNOWN_retrieved_odin_scoresOBJ_p1p3, bins=50, alpha=0.7, color='blue', edgecolor='black', hatch='//', label='Samples belonging to the knowns')
axs[0].hist(retrieved_odin_scoresOBJ_p1p3, bins=50, alpha=0.7, color='red', edgecolor='black', hatch='\\\\', label='Never seen before samples')

axs[0].set_title('ODIN scores of $\mathcal{K}$ and $\mathcal{N}$, Obj., $\mathcal{K} = p_1$, $\mathcal{I} = p_3$')
axs[0].set_xlabel('Value of the ODIN score')
axs[0].set_ylabel('Frequency of occurrence')
axs[0].legend(loc='upper right')
axs[0].grid(False)

axs[1].hist(openmax_scores_known_OBJp1p3, bins=50, alpha=0.7, color='blue', edgecolor='black', hatch='//', label='Samples belonging to the knowns')
axs[1].hist(openmax_scores_unknown_OBJp1p3, bins=50, alpha=0.7, color='red', edgecolor='black', hatch='\\\\', label='Never seen before samples')

axs[1].set_title('OpenMax scores of $\mathcal{K}$ and $\mathcal{N}$, Obj., $\mathcal{K} = p_1$, $\mathcal{I} = p_3$')
axs[1].set_xlabel('Value of the OpenMax score')
axs[1].set_ylabel('Frequency of occurrence')
axs[1].legend(loc='upper right')
axs[1].grid(False)

axs[2].hist(retrieved_Maha_scoresOBJ_p1p3, bins=50, alpha=0.7, color='blue', edgecolor='black', hatch='//', label='Samples belonging to the knowns')
axs[2].hist(KNOWN_retrieved_Maha_scoresOBJ_p1p3, bins=50, alpha=0.7, color='red', edgecolor='black', hatch='\\\\', label='Never seen before samples')

axs[2].set_title('Mahalanobis scores of $\mathcal{K}$ and $\mathcal{N}$, Obj., $\mathcal{K} = p_1$, $\mathcal{I} = p_3$')
axs[2].set_xlabel('Value of Mahalanobis score')
axs[2].set_ylabel('Frequency of occurrence')
axs[2].legend(loc='upper right')
axs[2].grid(False)

plt.tight_layout()

plt.show()

# %% [markdown]
# # Compute ODINs

# %% [markdown]
# # Naive $\mathcal{K} = p_1 + p_2$, $\mathcal{I} = ∅$

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

folder_path = "/content/gdrive/MyDrive/Stanford_data"

file_name = "all_odin_scores_NAIVEKp1p2.txt"

file_path = os.path.join(folder_path, file_name)

retrieved_odin_scoresK_p1p2 = []

if os.path.exists(file_path):
    with open(file_path, 'r') as file:
        retrieved_odin_scoresK_p1p2 = [float(line.strip()) for line in file.readlines()]

# %%
plt.hist(retrieved_odin_scoresK_p1p2, bins=10)

plt.xlabel('ODIN Score')
plt.ylabel('Frequency')
plt.title('Histogram of ODIN UNKNOWN Scores')

plt.show()

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

folder_path = "/content/gdrive/MyDrive/Stanford_data"

file_name = "KNOWN_all_odin_scores_NAIVEKp1p2.txt"

file_path = os.path.join(folder_path, file_name)

KNOWN_retrieved_odin_scoresK_p1p2 = []

if os.path.exists(file_path):
    with open(file_path, 'r') as file:
        KNOWN_retrieved_odin_scoresK_p1p2 = [float(line.strip()) for line in file.readlines()]

# %%
plt.hist(KNOWN_retrieved_odin_scoresK_p1p2, bins=10)

plt.xlabel('ODIN Score')
plt.ylabel('Frequency')
plt.title('Histogram of ODIN KNOWN Scores')

plt.show()

# %%
min(retrieved_odin_scoresK_p1p2)
# Out:
# 0.011636857874691486

# %%
max(KNOWN_retrieved_odin_scoresK_p1p2)
# Out:
# 4.3655745685100555e-08

# %% [markdown]
# # Naive, $\mathcal{K} = p_1 + p_2 + p_3$, $\mathcal{I} = \emptyset$

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

folder_path = "/content/gdrive/MyDrive/Stanford_data"

file_name = "all_odin_scores_NAIVEKp1p2p3.txt"

file_path = os.path.join(folder_path, file_name)

retrieved_odin_scoresK_p1p2p3 = []

if os.path.exists(file_path):
    with open(file_path, 'r') as file:
        retrieved_odin_scoresK_p1p2p3 = [float(line.strip()) for line in file.readlines()]

# %%
plt.hist(retrieved_odin_scoresK_p1p2p3, bins=10)

plt.xlabel('ODIN Score')
plt.ylabel('Frequency')
plt.title('Histogram of ODIN UNKNOWN Scores')

plt.show()

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

folder_path = "/content/gdrive/MyDrive/Stanford_data"

file_name = "KNOWN_all_odin_scores_NAIVEKp1p2p3.txt"

file_path = os.path.join(folder_path, file_name)

KNOWN_retrieved_odin_scoresK_p1p2p3 = []

if os.path.exists(file_path):
    with open(file_path, 'r') as file:
        KNOWN_retrieved_odin_scoresK_p1p2p3 = [float(line.strip()) for line in file.readlines()]

# %%
plt.hist(KNOWN_retrieved_odin_scoresK_p1p2p3, bins=10)

plt.xlabel('ODIN Score')
plt.ylabel('Frequency')
plt.title('Histogram of ODIN KNOWN Scores')

plt.show()

# %%
min(retrieved_odin_scoresK_p1p2p3)
# Out:
# 0.017969846725463867

# %%
max(KNOWN_retrieved_odin_scoresK_p1p2p3)
# Out:
# 5.407491698861122e-08

# %% [markdown]
# 0.017969846725463867,5.407491698861122e-08

# %% [markdown]
# #EOS $\mathcal{K} = p_1 + p_2$, $\mathcal{I} = p_3$

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

folder_path = "/content/gdrive/MyDrive/Stanford_data"

file_name = "all_odin_scores_EOSp1p2p3.txt"

file_path = os.path.join(folder_path, file_name)

retrieved_odin_scoresEOS_p1p2p3 = []

if os.path.exists(file_path):
    with open(file_path, 'r') as file:
        retrieved_odin_scoresEOS_p1p2p3 = [float(line.strip()) for line in file.readlines()]

# %%
plt.hist(retrieved_odin_scoresEOS_p1p2p3, bins=10)

plt.xlabel('ODIN Score')
plt.ylabel('Frequency')
plt.title('Histogram of ODIN UNKNOWN Scores')

plt.show()

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

folder_path = "/content/gdrive/MyDrive/Stanford_data"

file_name = "KNOWN_all_odin_scores_EOSp1p2p3.txt"

file_path = os.path.join(folder_path, file_name)

KNOWN_retrieved_odin_scoresEOS_p1p2p3 = []

if os.path.exists(file_path):
    with open(file_path, 'r') as file:
        KNOWN_retrieved_odin_scoresEOS_p1p2p3 = [float(line.strip()) for line in file.readlines()]

# %%
plt.hist(KNOWN_retrieved_odin_scoresEOS_p1p2p3, bins=10)

plt.xlabel('ODIN Score')
plt.ylabel('Frequency')
plt.title('Histogram of ODIN KNOWN Scores')

plt.show()

# %%
min(retrieved_odin_scoresEOS_p1p2p3)
# Out:
# 0.00016274643712677062

# %%
max(KNOWN_retrieved_odin_scoresEOS_p1p2p3)
# Out:
# 9.19681042432785e-09

# %% [markdown]
# # Obj, $\mathcal{K} = p_1 + p_2$, $\mathcal{I} = p_3$

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

folder_path = "/content/gdrive/MyDrive/Stanford_data"

file_name = "all_odin_scores_OBJp1p2p3.txt"

file_path = os.path.join(folder_path, file_name)

retrieved_odin_scoresOBJ_p1p2p3 = []

if os.path.exists(file_path):
    with open(file_path, 'r') as file:
        retrieved_odin_scoresOBJ_p1p2p3 = [float(line.strip()) for line in file.readlines()]

# %%
plt.hist(retrieved_odin_scoresOBJ_p1p2p3, bins=10)

plt.xlabel('ODIN Score')
plt.ylabel('Frequency')
plt.title('Histogram of ODIN UNKNOWN Scores')

plt.show()

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

folder_path = "/content/gdrive/MyDrive/Stanford_data"

file_name = "KNOWN_all_odin_scores_OBJp1p2p3.txt"

file_path = os.path.join(folder_path, file_name)

if os.path.exists(file_path):
    with open(file_path, 'r') as file:
        KNOWN_retrieved_odin_scoresOBJ_p1p2p3 = [float(line.strip()) for line in file.readlines()]

# %%
plt.hist(KNOWN_retrieved_odin_scoresOBJ_p1p2p3, bins=10)

plt.xlabel('ODIN Score')
plt.ylabel('Frequency')
plt.title('Histogram of ODIN KNOWN Scores')

plt.show()

# %%
min(retrieved_odin_scoresOBJ_p1p2p3)
# Out:
# 0.06692367792129517

# %%
max(KNOWN_retrieved_odin_scoresOBJ_p1p2p3)
# Out:
# 4.541128873825073e-06

# %%
0.011636857874691486,4.3655745685100555e-08

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.hist(retrieved_odin_scoresK_p1p2, bins=50, alpha=0.7, color='blue', edgecolor='black', hatch='//', label='Naive, $\mathcal{K} = p_1 + p_2$, $\mathcal{I} = \emptyset$,' '\n  $max(\mathcal{K}) = 1.2 \cdot 10^{-2}$, $min(\mathcal{N}) = 4.4 \cdot 10^{-8}$', linewidth=0.5)
plt.hist(retrieved_odin_scoresK_p1p2p3, bins=50, alpha=0.7, color='#FFC107', edgecolor='black', hatch='\\\\', label='Naive, $\mathcal{K} = p_1 + p_2 + p_3$, $\mathcal{I} = \emptyset$,' '\n  $max(\mathcal{K}) = 1.8 \cdot 10^{-2}$, $min(\mathcal{N}) = 5.4\cdot 10^{-8}$', linewidth=0.5)
plt.hist(retrieved_odin_scoresOBJ_p1p2p3, bins=50, alpha=0.7, color='green', edgecolor='black', hatch='.', label='Objectosphere, $\mathcal{K} = p_1 + p_2$, $\mathcal{I} = p_3$,' '\n  $max(\mathcal{K}) = 6.7 \cdot 10^{-2}$, $min(\mathcal{N}) = 4.5\cdot 10^{-6}$', linewidth=0.5)

plt.title('ODIN scores of $\mathcal{N}$, using $p_1$, $p_2$ and $p_3$ datasets')

plt.ylim(0, 1230)


plt.xlabel('Value of the ODIN score')
plt.ylabel('Frequency of occurrence')
plt.legend(loc='upper right')
plt.grid(False)

plt.show()

# %% [markdown]
# # OpenMax

# %% [markdown]
# # Naive, $\mathcal{K} = p_1 + p_2$, $\mathcal{I} = \emptyset$

# %%
import numpy as np
import matplotlib.pyplot as plt

file_path_known = '/content/gdrive/MyDrive/Stanford_data/NaiveKp1p2_combined_openmax_scores_known.txt'
file_path_unknown = '/content/gdrive/MyDrive/Stanford_data/NaiveKp1p2_combined_openmax_scores_unknown.txt'

openmax_scores_known_NaiveKp1p2 = np.loadtxt(file_path_known)
openmax_scores_unknown_NaiveKp1p2 = np.loadtxt(file_path_unknown)

plt.hist(openmax_scores_known_NaiveKp1p2, bins=50, alpha=0.5, color='blue', label='Known Data')
plt.hist(openmax_scores_unknown_NaiveKp1p2, bins=50, alpha=0.5, color='red', label='Unknown Data')
plt.xlabel('OpenMax Score')
plt.ylabel('Frequency')
plt.title('Histogram of OpenMax Scores')
plt.legend(loc='upper right')

plt.show()

# %%
min(openmax_scores_unknown_NaiveKp1p2)
# Out:
# 1.5942587197059765e-06

# %%
import numpy as np

# Define your threshold value
threshold = min(openmax_scores_unknown_NaiveKp1p2)

# Calculate the percentage of values smaller than the threshold
percentage_below_threshold = np.mean(openmax_scores_known_NaiveKp1p2 < threshold) * 100

print(f"Percentage of values below {threshold}: {percentage_below_threshold:.2f}%")
# Out:
# Percentage of values below 1.5942587197059765e-06: 18.66%

# %% [markdown]
# # Naive, $\mathcal{K} = p_1 + p_2 + p_3$, $\mathcal{I} = \emptyset$

# %%
import numpy as np
import matplotlib.pyplot as plt

file_path_known = '/content/gdrive/MyDrive/Stanford_data/NaiveKp1p2p3_combined_openmax_scores_known.txt'
file_path_unknown = '/content/gdrive/MyDrive/Stanford_data/NaiveKp1p2p3_combined_openmax_scores_unknown.txt'

openmax_scores_known_Naivep1p2p3 = np.loadtxt(file_path_known)
openmax_scores_unknown_Naivep1p2p3 = np.loadtxt(file_path_unknown)

plt.hist(openmax_scores_known_Naivep1p2p3, bins=50, alpha=0.5, color='blue', label='Known Data')
plt.hist(openmax_scores_unknown_Naivep1p2p3, bins=50, alpha=0.5, color='red', label='Unknown Data')
plt.xlabel('OpenMax Score')
plt.ylabel('Frequency')
plt.title('Histogram of OpenMax Scores')
plt.legend(loc='upper right')

plt.show()

# %%
import numpy as np

threshold = min(openmax_scores_unknown_Naivep1p2p3)

percentage_below_threshold = np.mean(openmax_scores_known_Naivep1p2p3 < threshold) * 100

print(f"Percentage of values below {threshold}: {percentage_below_threshold:.2f}%")
# Out:
# Percentage of values below 1.3357550869841361e-06: 57.06%

# %% [markdown]
# #EOS, $\mathcal{K} = p_1 + p_2$, $\mathcal{I} = p_3$

# %%
import numpy as np
import matplotlib.pyplot as plt

file_path_known = '/content/gdrive/MyDrive/Stanford_data/EOSp1p2p3_combined_openmax_scores_known.txt'
file_path_unknown = '/content/gdrive/MyDrive/Stanford_data/EOSp1p2p3_combined_openmax_scores_unknown.txt'

openmax_scores_known_EOSp1p2p3 = np.loadtxt(file_path_known)
openmax_scores_unknown_EOSp1p2p3 = np.loadtxt(file_path_unknown)

plt.hist(openmax_scores_known_EOSp1p2p3, bins=50, alpha=0.5, color='blue', label='Known Data')
plt.hist(openmax_scores_unknown_EOSp1p2p3, bins=50, alpha=0.5, color='red', label='Unknown Data')
plt.xlabel('OpenMax Score')
plt.ylabel('Frequency')
plt.title('Histogram of OpenMax Scores')
plt.legend(loc='upper right')

plt.show()

# %%
import numpy as np

threshold = min(openmax_scores_unknown_EOSp1p2p3)

percentage_below_threshold = np.mean(openmax_scores_known_EOSp1p2p3 < threshold) * 100

print(f"Percentage of values below {threshold}: {percentage_below_threshold:.2f}%")
# Out:
# Percentage of values below 3.5048453810304636e-06: 38.79%

# %% [markdown]
# # Obj, $\mathcal{K} = p_1 + p_2$, $\mathcal{I} = p_3$

# %%
import numpy as np
import matplotlib.pyplot as plt

file_path_known = '/content/gdrive/MyDrive/Stanford_data/OBJp1p2p3_combined_openmax_scores_known.txt'
file_path_unknown = '/content/gdrive/MyDrive/Stanford_data/OBJp1p2p3_combined_openmax_scores_unknown.txt'

openmax_scores_known_OBJp1p2p3 = np.loadtxt(file_path_known)
openmax_scores_unknown_OBJp1p2p3 = np.loadtxt(file_path_unknown)

plt.hist(openmax_scores_known_OBJp1p2p3, bins=50, alpha=0.5, color='blue', label='Known Data')
plt.hist(openmax_scores_unknown_OBJp1p2p3, bins=50, alpha=0.5, color='red', label='Unknown Data')
plt.xlabel('OpenMax Score')
plt.ylabel('Frequency')
plt.title('Histogram of OpenMax Scores')
plt.legend(loc='upper right')

plt.show()

# %%
import numpy as np

threshold = min(openmax_scores_unknown_OBJp1p2p3)

percentage_below_threshold = np.mean(openmax_scores_known_OBJp1p2p3 < threshold) * 100

print(f"Percentage of values below {threshold}: {percentage_below_threshold:.2f}%")
# Out:
# Percentage of values below 9.835468972596573e-08: 17.31%

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.hist(openmax_scores_unknown_NaiveKp1p2, bins=50, alpha=0.7, color='blue', edgecolor='black', hatch='//', label='Naive, $\mathcal{K} = p_1 + p_2$, $\mathcal{I} = \emptyset$')
plt.hist(openmax_scores_unknown_Naivep1p2p3, bins=50, alpha=0.7, color='#FFC107', edgecolor='black', hatch='\\\\', label='Naive, $\mathcal{K} = p_1 + p_2 + p_3$')
plt.hist(openmax_scores_unknown_OBJp1p2p3, bins=50, alpha=0.7, color='green', edgecolor='black', hatch='.', label='Objectosphere, $\mathcal{K} = p_1 + p_2$, $\mathcal{I} = p_3$')

plt.title('OpenMax scores of $\mathcal{N}$, using $p_1$, $p_2$ and $p_3$ datasets')
plt.xlabel('Value of the OpenMax score')
plt.ylabel('Frequency of occurrence')
plt.legend(loc='upper center')
plt.grid(False)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.hist(retrieved_odin_scoresK_p1, bins=50, alpha=0.7, color='blue', edgecolor='black', hatch='//', label='Naive, $\mathcal{K} = p_1$, $\mathcal{I} = \emptyset$,' '\n  $min(\mathcal{N}) = 8.8 \cdot 10^{-3}$, $max(\mathcal{K}) = 2.6\cdot 10^{-8}$', linewidth=0.5)
plt.hist(retrieved_odin_scoresK_p1p3, bins=50, alpha=0.7, color='#FFC107', edgecolor='black', hatch='\\\\', label='Naive, $\mathcal{K} = p_1 + p_3$, $\mathcal{I} = \emptyset$,' '\n  $min(\mathcal{N}) = 1.6 \cdot 10^{-2}$, $max(\mathcal{K}) = 3.4\cdot 10^{-8}$', linewidth=0.5)
plt.hist(retrieved_odin_scoresOBJ_p1p3, bins=50, alpha=0.7, color='green', edgecolor='black', hatch='.', label='Objectosphere, $\mathcal{K} = p_1$, $\mathcal{I} = p_3$,' '\n  $min (\mathcal{N}) = 3.5 \cdot 10^{-2}$, $max(\mathcal{K}) = 4.7\cdot 10^{-6}$', linewidth=0.5)

plt.title('ODIN scores of $\mathcal{N}$, using $p_1$ and $p_3$ datasets')
plt.xlabel('Value of the ODIN score')
plt.ylabel('Frequency of occurrence')
plt.legend(loc='upper right')
plt.grid(False)

plt.show()

import matplotlib.pyplot as plt
import numpy as np

plt.hist(retrieved_odin_scoresK_p1p2, bins=50, alpha=0.7, color='blue', edgecolor='black', hatch='//', label='Naive, $\mathcal{K} = p_1 + p_2$, $\mathcal{I} = \emptyset$,' '\n  $min(\mathcal{N}) = 1.2 \cdot 10^{-2}$, $max(\mathcal{K}) = 4.4 \cdot 10^{-8}$', linewidth=0.5)
plt.hist(retrieved_odin_scoresK_p1p2p3, bins=50, alpha=0.7, color='#FFC107', edgecolor='black', hatch='\\\\', label='Naive, $\mathcal{K} = p_1 + p_2 + p_3$, $\mathcal{I} = \emptyset$,' '\n  $min(\mathcal{N}) = 1.8 \cdot 10^{-2}$, $max(\mathcal{K}) = 5.4\cdot 10^{-8}$', linewidth=0.5)
plt.hist(retrieved_odin_scoresOBJ_p1p2p3, bins=50, alpha=0.7, color='green', edgecolor='black', hatch='.', label='Objectosphere, $\mathcal{K} = p_1 + p_2$, $\mathcal{I} = p_3$,' '\n  $min(\mathcal{N}) = 6.7 \cdot 10^{-2}$, $max(\mathcal{K}) = 4.5\cdot 10^{-6}$', linewidth=0.5)

plt.title('ODIN scores of $\mathcal{N}$, using $p_1$, $p_2$ and $p_3$ datasets')

plt.ylim(0, 1230)

plt.xlabel('Value of the ODIN score')
plt.ylabel('Frequency of occurrence')
plt.legend(loc='upper right')
plt.grid(False)

plt.show()

import matplotlib.pyplot as plt
import numpy as np

plt.hist(openmax_scores_unknown_NaiveKp1, bins=50, alpha=0.7, color='blue', edgecolor='black', hatch='//', label='Naive, $\mathcal{K} = p_1$, $\mathcal{I} = \emptyset$')
plt.hist(openmax_scores_unknown_Naivep1p3, bins=50, alpha=0.7, color='#FFC107', edgecolor='black', hatch='\\\\', label='Naive, $\mathcal{K} = p_1 + p_3$')
plt.hist(openmax_scores_unknown_OBJp1p3, bins=50, alpha=0.7, color='green', edgecolor='black', hatch='.', label='Objectosphere, $\mathcal{K} = p_1$, $\mathcal{I} = p_3$')


plt.title('OpenMax scores of $\mathcal{N}$, using $p_1$ and $p_3$ datasets')
plt.xlabel('Value of the OpenMax score')
plt.ylabel('Frequency of occurrence')
plt.legend(loc='upper center')
plt.grid(False)

plt.show()

import matplotlib.pyplot as plt
import numpy as np

plt.hist(openmax_scores_unknown_NaiveKp1p2, bins=50, alpha=0.7, color='blue', edgecolor='black', hatch='//', label='Naive, $\mathcal{K} = p_1 + p_2$, $\mathcal{I} = \emptyset$')
plt.hist(openmax_scores_unknown_Naivep1p2p3, bins=50, alpha=0.7, color='#FFC107', edgecolor='black', hatch='\\\\', label='Naive, $\mathcal{K} = p_1 + p_2 + p_3$')
plt.hist(openmax_scores_unknown_OBJp1p2p3, bins=50, alpha=0.7, color='green', edgecolor='black', hatch='.', label='Objectosphere, $\mathcal{K} = p_1 + p_2$, $\mathcal{I} = p_3$')


plt.title('OpenMax scores of $\mathcal{N}$, using $p_1$, $p_2$ and $p_3$ datasets')
plt.xlabel('Value of the OpenMax score')
plt.ylabel('Frequency of occurrence')
plt.legend(loc='upper center')
plt.grid(False)

plt.show()

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

folder_path = "/content/gdrive/MyDrive/Stanford_data"

file_name = "mahalanobis_distances_unknown_combined_OBJp1p2p3.txt"

file_path = os.path.join(folder_path, file_name)

retrieved_Maha_scoresOBJ_p1p2p3 = []

if os.path.exists(file_path):
    with open(file_path, 'r') as file:
        retrieved_Maha_scoresOBJ_p1p2p3 = [float(line.strip()) for line in file.readlines()]

plt.hist(retrieved_Maha_scoresOBJ_p1p2p3, bins=10)

plt.xlabel('Mahalanobis Score')
plt.ylabel('Frequency')
plt.title('Histogram of Mahalanobis UNKNOWN Scores')

plt.show()

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

folder_path = "/content/gdrive/MyDrive/Stanford_data"

file_name = "mahalanobis_distances_known_combined_OBJp1p2p3.txt"

file_path = os.path.join(folder_path, file_name)

KNOWN_retrieved_Maha_scoresOBJ_p1p2p3 = []

if os.path.exists(file_path):
    with open(file_path, 'r') as file:
        KNOWN_retrieved_Maha_scoresOBJ_p1p2p3 = [float(line.strip()) for line in file.readlines()]


import matplotlib.pyplot as plt
import numpy as np

plt.hist(retrieved_Maha_scoresOBJ_p1p2p3, bins=50, alpha=0.7, color='blue', edgecolor='black', hatch='/', label='Retrieved Mahalanobis Scores')
plt.hist(KNOWN_retrieved_Maha_scoresOBJ_p1p2p3, bins=50, alpha=0.7, color='red', edgecolor='black', hatch='\\', label='KNOWN Retrieved Mahalanobis Scores')

plt.title('Comparison of Retrieved Mahalanobis Scores')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend(loc='upper right')
plt.grid(False)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, axs = plt.subplots(1, 3, figsize=(18, 4))

axs[0].hist(KNOWN_retrieved_odin_scoresOBJ_p1p2p3, bins=50, alpha=0.7, color='blue', edgecolor='black', hatch='//', label='Samples belonging to the knowns')
axs[0].hist(retrieved_odin_scoresOBJ_p1p2p3, bins=50, alpha=0.7, color='red', edgecolor='black', hatch='\\\\', label='Never seen before samples')

axs[0].set_title('ODIN scores of $\mathcal{K}$ and $\mathcal{N}$, Obj., $\mathcal{K} = p_1 + p_2$, $\mathcal{I} = p_3$')
axs[0].set_xlabel('Value of the ODIN score')
axs[0].set_ylabel('Frequency of occurrence')
axs[0].legend(loc='upper right')
axs[0].grid(False)

axs[1].hist(openmax_scores_known_OBJp1p2p3, bins=50, alpha=0.7, color='blue', edgecolor='black', hatch='//', label='Samples belonging to the knowns')
axs[1].hist(openmax_scores_unknown_OBJp1p2p3, bins=50, alpha=0.7, color='red', edgecolor='black', hatch='\\\\', label='Never seen before samples')

axs[1].set_title('OpenMax scores of $\mathcal{K}$ and $\mathcal{N}$, Obj., $\mathcal{K} = p_1 + p_2$, $\mathcal{I} = p_3$')
axs[1].set_xlabel('Value of the OpenMax score')
axs[1].set_ylabel('Frequency of occurrence')
axs[1].legend(loc='upper right')
axs[1].grid(False)

axs[2].hist(retrieved_Maha_scoresOBJ_p1p2p3, bins=50, alpha=0.7, color='blue', edgecolor='black', hatch='//', label='Samples belonging to the knowns')
axs[2].hist(KNOWN_retrieved_Maha_scoresOBJ_p1p2p3, bins=50, alpha=0.7, color='red', edgecolor='black', hatch='\\\\', label='Never seen before samples')

axs[2].set_title('Mahalanobis scores of $\mathcal{K}$ and $\mathcal{N}$, Obj., $\mathcal{K} = p_1 + p_2$, $\mathcal{I} = p_3$')
axs[2].set_xlabel('Value of Mahalanobis score')
axs[2].set_ylabel('Frequency of occurrence')
axs[2].legend(loc='upper right')
axs[2].set_ylim(0, 100)

axs[2].grid(False)

plt.tight_layout()

plt.show()
